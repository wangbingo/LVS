# %% [markdown]
# <a href="https://colab.research.google.com/github/wangbingo/LVS/blob/master/mmaction_test_on_UCF_101_201909211200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation(skip Install dense_flow (Optional))

# %% [markdown]
# installation

# %%
# !git clone --recursive https://github.com/open-mmlab/mmaction.git

# %% [markdown]
# Install Pre-requisites.
# Install Decord (Optional)

# %%
# !sudo apt-get install -y software-properties-common

# %%
# !sudo add-apt-repository ppa:jonathonf/ffmpeg-4

# %%
# !sudo apt-get update

# %%
# !sudo apt-get install -y build-essential python3-dev python3-setuptools make cmake libavcodec-dev libavfilter-dev libavformat-dev libavutil-dev

# %%
# !sudo apt-get install ffmpeg

# %%
# !cd mmaction/third_party/decord && mkdir build && cd build && cmake .. -DUSE_CUDA=0 && make

# %%
# !cd mmaction/third_party/decord/python/  &&  python setup.py install --user

# %% [markdown]
# Install MMAction

# %%
# !pip install cython
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (0.29.13)

# %%
# !cd mmaction/  && sh  ./compile.sh
# Out:
# Building package resample2d
# running install
# running bdist_egg
# running egg_info
# creating resample2d_cuda.egg-info
# writing resample2d_cuda.egg-info/PKG-INFO
# writing dependency_links to resample2d_cuda.egg-info/dependency_links.txt
# writing top-level names to resample2d_cuda.egg-info/top_level.txt
# writing manifest file 'resample2d_cuda.egg-info/SOURCES.txt'
# writing manifest file 'resample2d_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'resample2d_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c resample2d_cuda.cc -o build/temp.linux-x86_64-3.6/resample2d_cuda.o -std=c++11 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=resample2d_cuda -D_GLIBCXX_USE_CXX11_ABI=0
# In file included from resample2d_cuda.cc:2:0:
# /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/torch.h:7:2: warning: #warning "Including torch/torch.h for C++ extensions is deprecated. Please include torch/extension.h" [-Wcpp]
#  #warning \
#   ^~~~~~~
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c resample2d_kernel.cu -o build/temp.linux-x86_64-3.6/resample2d_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_70,code=compute_70 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=resample2d_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# creating build/lib.linux-x86_64-3.6
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/resample2d_cuda.o build/temp.linux-x86_64-3.6/resample2d_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/resample2d_cuda.cpython-36m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.6/resample2d_cuda.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for resample2d_cuda.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/resample2d_cuda.py to resample2d_cuda.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying resample2d_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.resample2d_cuda.cpython-36: module references __file__
# creating dist
# creating 'dist/resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg
# creating /root/.local/lib/python3.6/site-packages/resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg
# Extracting resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg to /root/.local/lib/python3.6/site-packages
# Adding resample2d-cuda 0.0.0 to easy-install.pth file
#
# Installed /root/.local/lib/python3.6/site-packages/resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg
# Processing dependencies for resample2d-cuda==0.0.0
# Finished processing dependencies for resample2d-cuda==0.0.0
# Building package trajectory_conv...
# running install
# running bdist_egg
# running egg_info
# creating traj_conv_cuda.egg-info
# writing traj_conv_cuda.egg-info/PKG-INFO
# writing dependency_links to traj_conv_cuda.egg-info/dependency_links.txt
# writing top-level names to traj_conv_cuda.egg-info/top_level.txt
# writing manifest file 'traj_conv_cuda.egg-info/SOURCES.txt'
# writing manifest file 'traj_conv_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'traj_conv_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c traj_conv_cuda.cpp -o build/temp.linux-x86_64-3.6/traj_conv_cuda.o -std=c++11 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=traj_conv_cuda -D_GLIBCXX_USE_CXX11_ABI=0
# In file included from traj_conv_cuda.cpp:2:0:
# /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/torch.h:7:2: warning: #warning "Including torch/torch.h for C++ extensions is deprecated. Please include torch/extension.h" [-Wcpp]
#  #warning \
#   ^~~~~~~
# traj_conv_cuda.cpp: In function ‘int deform_3d_conv_forward_cuda(at::Tensor&, at::Tensor&, at::Tensor&, at::Tensor&, at::Tensor&, at::Tensor&, at::Tensor&, int, int, int, int, int, int, int, int, int, int, int, int, int, int)’:
# traj_conv_cuda.cpp:127:7: warning: variable ‘batch’ set but not used [-Wunused-but-set-variable]
#    int batch = 1;
#        ^~~~~
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c deform_3d_conv_cuda_kernel.cu -o build/temp.linux-x86_64-3.6/deform_3d_conv_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_70,code=compute_70 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=traj_conv_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# deform_3d_conv_cuda_kernel.cu: In lambda function:
# deform_3d_conv_cuda_kernel.cu:244:124: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(
#                                                                                                                             ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# deform_3d_conv_cuda_kernel.cu: In lambda function:
# deform_3d_conv_cuda_kernel.cu:344:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(data_col.type(), "deformable_col2im_kernel", ([&] {
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# deform_3d_conv_cuda_kernel.cu: In lambda function:
# deform_3d_conv_cuda_kernel.cu:447:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(data_col.type(), "deformable_col2im_coord_kernel", ([&] {
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# creating build/lib.linux-x86_64-3.6
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/traj_conv_cuda.o build/temp.linux-x86_64-3.6/deform_3d_conv_cuda_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/traj_conv_cuda.cpython-36m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.6/traj_conv_cuda.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for traj_conv_cuda.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/traj_conv_cuda.py to traj_conv_cuda.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying traj_conv_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying traj_conv_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying traj_conv_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying traj_conv_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.traj_conv_cuda.cpython-36: module references __file__
# creating dist
# creating 'dist/traj_conv_cuda-0.0.0-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing traj_conv_cuda-0.0.0-py3.6-linux-x86_64.egg
# creating /root/.local/lib/python3.6/site-packages/traj_conv_cuda-0.0.0-py3.6-linux-x86_64.egg
# Extracting traj_conv_cuda-0.0.0-py3.6-linux-x86_64.egg to /root/.local/lib/python3.6/site-packages
# Adding traj-conv-cuda 0.0.0 to easy-install.pth file
#
# Installed /root/.local/lib/python3.6/site-packages/traj_conv_cuda-0.0.0-py3.6-linux-x86_64.egg
# Processing dependencies for traj-conv-cuda==0.0.0
# Finished processing dependencies for traj-conv-cuda==0.0.0
# Building roi align op...
# running build_ext
# building 'roi_align_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/src
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/roi_align_cuda.cpp -o build/temp.linux-x86_64-3.6/src/roi_align_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=roi_align_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/roi_align_kernel.cu -o build/temp.linux-x86_64-3.6/src/roi_align_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=roi_align_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# src/roi_align_kernel.cu: In lambda function:
# src/roi_align_kernel.cu:133:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# src/roi_align_kernel.cu: In lambda function:
# src/roi_align_kernel.cu:276:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# creating build/lib.linux-x86_64-3.6
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/src/roi_align_cuda.o build/temp.linux-x86_64-3.6/src/roi_align_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/roi_align_cuda.cpython-36m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.6/roi_align_cuda.cpython-36m-x86_64-linux-gnu.so ->
# Building roi pool op...
# running build_ext
# building 'roi_pool_cuda' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/src
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/roi_pool_cuda.cpp -o build/temp.linux-x86_64-3.6/src/roi_pool_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=roi_pool_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/roi_pool_kernel.cu -o build/temp.linux-x86_64-3.6/src/roi_pool_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=roi_pool_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(83): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lowest") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(84): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("max") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(85): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("lower_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/cuda/NumericLimits.cuh(86): warning: calling a constexpr __host__ function("from_bits") from a __host__ __device__ function("upper_bound") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# src/roi_pool_kernel.cu: In lambda function:
# src/roi_pool_kernel.cu:88:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# src/roi_pool_kernel.cu: In lambda function:
# src/roi_pool_kernel.cu:136:126: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#    AT_DISPATCH_FLOATING_TYPES_AND_HALF(
#                                                                                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#  ^~~~~~~~~~~
# creating build/lib.linux-x86_64-3.6
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/src/roi_pool_cuda.o build/temp.linux-x86_64-3.6/src/roi_pool_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/roi_pool_cuda.cpython-36m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.6/roi_pool_cuda.cpython-36m-x86_64-linux-gnu.so ->
# Building nms op...
# running build_ext
# building 'soft_nms_cpu' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/src
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c src/soft_nms_cpu.cpp -o build/temp.linux-x86_64-3.6/src/soft_nms_cpu.o -Wno-unused-function -Wno-write-strings
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from src/soft_nms_cpu.cpp:655:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# src/soft_nms_cpu.cpp: In function ‘PyObject* __pyx_pf_12soft_nms_cpu_soft_nms_cpu(PyObject*, PyArrayObject*, float, unsigned int, float, float)’:
# src/soft_nms_cpu.cpp:2483:34: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        __pyx_t_10 = ((__pyx_v_pos < __pyx_v_N) != 0);
#                       ~~~~~~~~~~~~^~~~~~~~~~~
# src/soft_nms_cpu.cpp:2994:34: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        __pyx_t_10 = ((__pyx_v_pos < __pyx_v_N) != 0);
#                       ~~~~~~~~~~~~^~~~~~~~~~~
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/src/soft_nms_cpu.o -o /content/mmaction/mmaction/ops/nms/soft_nms_cpu.cpython-36m-x86_64-linux-gnu.so
# running build_ext
# building 'nms_cuda' extension
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/nms_cuda.cpp -o build/temp.linux-x86_64-3.6/src/nms_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=nms_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/nms_kernel.cu -o build/temp.linux-x86_64-3.6/src/nms_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=nms_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# creating build/lib.linux-x86_64-3.6
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/src/nms_cuda.o build/temp.linux-x86_64-3.6/src/nms_kernel.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/nms_cuda.cpython-36m-x86_64-linux-gnu.so
# building 'nms_cpu' extension
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/include -I/usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.6/dist-packages/torch/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c src/nms_cpu.cpp -o build/temp.linux-x86_64-3.6/src/nms_cpu.o -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=nms_cpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++11
# In file included from /usr/local/lib/python3.6/dist-packages/torch/include/ATen/ATen.h:9:0,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:4,
#                  from /usr/local/lib/python3.6/dist-packages/torch/include/torch/extension.h:4,
#                  from src/nms_cpu.cpp:2:
# src/nms_cpu.cpp: In lambda function:
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:71:52: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated [-Wdeprecated-declarations]
#      at::ScalarType _st = ::detail::scalar_type(TYPE);                        \
#                                                     ^
# src/nms_cpu.cpp:63:3: note: in expansion of macro ‘AT_DISPATCH_FLOATING_TYPES’
#    AT_DISPATCH_FLOATING_TYPES(dets.type(), "nms", [&] {
#    ^~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/include/ATen/Dispatch.h:47:23: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties &t) {
#                        ^~~~~~~~~~~
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/src/nms_cpu.o -L/usr/local/cuda/lib64 -lcudart -o build/lib.linux-x86_64-3.6/nms_cpu.cpython-36m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.6/nms_cuda.cpython-36m-x86_64-linux-gnu.so ->
# copying build/lib.linux-x86_64-3.6/nms_cpu.cpython-36m-x86_64-linux-gnu.so ->

# %%
# !cd mmaction/  &&  python setup.py develop
# Out:
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:474: UserWarning: Normalizing '0.1.rc0+5f0e93f' to '0.1rc0+5f0e93f'
#   normalized_version,
# running develop
# running egg_info
# creating mmaction.egg-info
# writing mmaction.egg-info/PKG-INFO
# writing dependency_links to mmaction.egg-info/dependency_links.txt
# writing requirements to mmaction.egg-info/requires.txt
# writing top-level names to mmaction.egg-info/top_level.txt
# writing manifest file 'mmaction.egg-info/SOURCES.txt'
# writing manifest file 'mmaction.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/mmaction.egg-link (link to .)
# Adding mmaction 0.1rc0+5f0e93f to easy-install.pth file
#
# Installed /content/mmaction
# Processing dependencies for mmaction==0.1rc0+5f0e93f
# Searching for terminaltables
# Reading https://pypi.org/simple/terminaltables/
# Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz#sha256=f3eb0eb92e3833972ac36796293ca0906e998dc3be91fbe1f8615b331b853b81
# Best match: terminaltables 3.1.0
# Processing terminaltables-3.1.0.tar.gz
# Writing /tmp/easy_install-6whbs3px/terminaltables-3.1.0/setup.cfg
# Running terminaltables-3.1.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-6whbs3px/terminaltables-3.1.0/egg-dist-tmp-a0qk6q09
# Moving terminaltables-3.1.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding terminaltables 3.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/terminaltables-3.1.0-py3.6.egg
# Searching for mmcv
# Reading https://pypi.org/simple/mmcv/
# Downloading https://files.pythonhosted.org/packages/86/98/2db09740465707361f363f8644c71c98d0d9fe28c1f2e5821f8c5a4ee5ba/mmcv-0.2.13.tar.gz#sha256=edd7b221641333e01c2ad4301a1b80ee0f69166e0666fd2aca6b9898c995a197
# Best match: mmcv 0.2.13
# Processing mmcv-0.2.13.tar.gz
# Writing /tmp/easy_install-14urks0q/mmcv-0.2.13/setup.cfg
# Running mmcv-0.2.13/setup.py -q bdist_egg --dist-dir /tmp/easy_install-14urks0q/mmcv-0.2.13/egg-dist-tmp-jwlslnbe
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/easy_install-14urks0q/mmcv-0.2.13/mmcv/video/optflow_warp/flow_warp_module.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from ./mmcv/video/optflow_warp/flow_warp_module.cpp:612:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# creating /usr/local/lib/python3.6/dist-packages/mmcv-0.2.13-py3.6-linux-x86_64.egg
# Extracting mmcv-0.2.13-py3.6-linux-x86_64.egg to /usr/local/lib/python3.6/dist-packages
# Adding mmcv 0.2.13 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/mmcv-0.2.13-py3.6-linux-x86_64.egg
# Searching for addict
# Reading https://pypi.org/simple/addict/
# Downloading https://files.pythonhosted.org/packages/14/6f/beb258220417c1a0fe11e842f2e012a1be7eeeaa72a1d10ba17a804da367/addict-2.2.1-py3-none-any.whl#sha256=1948c2a5d93ba6026eb91aef2c971234aaf72488a9c07ab8a7950f82ae30eea7
# Best match: addict 2.2.1
# Processing addict-2.2.1-py3-none-any.whl
# Installing addict-2.2.1-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding addict 2.2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/addict-2.2.1-py3.6.egg
# Searching for joblib==0.13.2
# Best match: joblib 0.13.2
# Adding joblib 0.13.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for lmdb==0.97
# Best match: lmdb 0.97
# Adding lmdb 0.97 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scikit-learn==0.21.3
# Best match: scikit-learn 0.21.3
# Adding scikit-learn 0.21.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scipy==1.3.1
# Best match: scipy 1.3.1
# Adding scipy 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.16.5
# Best match: numpy 1.16.5
# Adding numpy 1.16.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Cython==0.29.13
# Best match: Cython 0.29.13
# Adding Cython 0.29.13 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for opencv-python==3.4.5.20
# Best match: opencv-python 3.4.5.20
# Adding opencv-python 3.4.5.20 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests==2.21.0
# Best match: requests 2.21.0
# Adding requests 2.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.8
# Best match: idna 2.8
# Adding idna 2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2019.6.16
# Best match: certifi 2019.6.16
# Adding certifi 2019.6.16 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for mmaction==0.1rc0+5f0e93f

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# Preparing UCF-101

# %%
! cd mmaction/data_tools/ucf101/ && bash download_annotations.sh
# Out:
# ../../data/ucf101/annotations does not exist. Creating
# --2019-09-20 14:27:18--  https://www.crcv.ucf.edu/data/UCF101/UCF101TrainTestSplits-RecognitionTask.zip
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113943 (111K) [application/zip]
# Saving to: ‘UCF101TrainTestSplits-RecognitionTask.zip’
#
# UCF101TrainTestSpli 100%[===================>] 111.27K  --.-KB/s    in 0.08s
#
# 2019-09-20 14:27:18 (1.42 MB/s) - ‘UCF101TrainTestSplits-RecognitionTask.zip’ saved [113943/113943]
#
# Archive:  UCF101TrainTestSplits-RecognitionTask.zip
#   inflating: ../../data/ucf101/annotations/classInd.txt
#   inflating: ../../data/ucf101/annotations/testlist01.txt
#   inflating: ../../data/ucf101/annotations/testlist02.txt
#   inflating: ../../data/ucf101/annotations/testlist03.txt
#   inflating: ../../data/ucf101/annotations/trainlist01.txt
#   inflating: ../../data/ucf101/annotations/trainlist02.txt
#   inflating: ../../data/ucf101/annotations/trainlist03.txt

# %%
! cd mmaction/data_tools/ucf101/ && bash download_videos.sh

# %%
# !cd mmaction/data_tools/ &&  python build_rawframes.py ../data/ucf101/videos/ ../data/ucf101/rawframes/ --level 2 --ext avi
# Out:
# Creating folder: ../data/ucf101/rawframes/PullUps
# Creating folder: ../data/ucf101/rawframes/FrontCrawl
# Creating folder: ../data/ucf101/rawframes/CliffDiving
# Creating folder: ../data/ucf101/rawframes/PlayingGuitar
# Creating folder: ../data/ucf101/rawframes/Punch
# Creating folder: ../data/ucf101/rawframes/ShavingBeard
# Creating folder: ../data/ucf101/rawframes/PlayingViolin
# Creating folder: ../data/ucf101/rawframes/JavelinThrow
# Creating folder: ../data/ucf101/rawframes/BlowingCandles
# Creating folder: ../data/ucf101/rawframes/JumpRope
# Creating folder: ../data/ucf101/rawframes/RopeClimbing
# Creating folder: ../data/ucf101/rawframes/Fencing
# Creating folder: ../data/ucf101/rawframes/PlayingCello
# Creating folder: ../data/ucf101/rawframes/TrampolineJumping
# Creating folder: ../data/ucf101/rawframes/CricketShot
# Creating folder: ../data/ucf101/rawframes/SalsaSpin
# Creating folder: ../data/ucf101/rawframes/BenchPress
# Creating folder: ../data/ucf101/rawframes/HammerThrow
# Creating folder: ../data/ucf101/rawframes/PommelHorse
# Creating folder: ../data/ucf101/rawframes/Bowling
# Creating folder: ../data/ucf101/rawframes/WritingOnBoard
# Creating folder: ../data/ucf101/rawframes/PlayingDhol
# Creating folder: ../data/ucf101/rawframes/Archery
# Creating folder: ../data/ucf101/rawframes/Rafting
# Creating folder: ../data/ucf101/rawframes/Swing
# Creating folder: ../data/ucf101/rawframes/TableTennisShot
# Creating folder: ../data/ucf101/rawframes/HeadMassage
# Creating folder: ../data/ucf101/rawframes/Drumming
# Creating folder: ../data/ucf101/rawframes/Mixing
# Creating folder: ../data/ucf101/rawframes/BrushingTeeth
# Creating folder: ../data/ucf101/rawframes/Hammering
# Creating folder: ../data/ucf101/rawframes/PlayingTabla
# Creating folder: ../data/ucf101/rawframes/LongJump
# Creating folder: ../data/ucf101/rawframes/Billiards
# Creating folder: ../data/ucf101/rawframes/PlayingSitar
# Creating folder: ../data/ucf101/rawframes/BreastStroke
# Creating folder: ../data/ucf101/rawframes/PlayingPiano
# Creating folder: ../data/ucf101/rawframes/Knitting
# Creating folder: ../data/ucf101/rawframes/Haircut
# Creating folder: ../data/ucf101/rawframes/JumpingJack
# Creating folder: ../data/ucf101/rawframes/Basketball
# Creating folder: ../data/ucf101/rawframes/SumoWrestling
# Creating folder: ../data/ucf101/rawframes/Typing
# Creating folder: ../data/ucf101/rawframes/ThrowDiscus
# Creating folder: ../data/ucf101/rawframes/ParallelBars
# Creating folder: ../data/ucf101/rawframes/HandstandWalking
# Creating folder: ../data/ucf101/rawframes/VolleyballSpiking
# Creating folder: ../data/ucf101/rawframes/HulaHoop
# Creating folder: ../data/ucf101/rawframes/MoppingFloor
# Creating folder: ../data/ucf101/rawframes/ApplyLipstick
# Creating folder: ../data/ucf101/rawframes/Diving
# Creating folder: ../data/ucf101/rawframes/Shotput
# Creating folder: ../data/ucf101/rawframes/BasketballDunk
# Creating folder: ../data/ucf101/rawframes/TaiChi
# Creating folder: ../data/ucf101/rawframes/Nunchucks
# Creating folder: ../data/ucf101/rawframes/WalkingWithDog
# Creating folder: ../data/ucf101/rawframes/UCF-101
# Creating folder: ../data/ucf101/rawframes/BlowDryHair
# Creating folder: ../data/ucf101/rawframes/RockClimbingIndoor
# Creating folder: ../data/ucf101/rawframes/Kayaking
# Creating folder: ../data/ucf101/rawframes/SoccerJuggling
# Creating folder: ../data/ucf101/rawframes/BabyCrawling
# Creating folder: ../data/ucf101/rawframes/SkateBoarding
# Creating folder: ../data/ucf101/rawframes/IceDancing
# Creating folder: ../data/ucf101/rawframes/YoYo
# Creating folder: ../data/ucf101/rawframes/HorseRace
# Creating folder: ../data/ucf101/rawframes/BaseballPitch
# Creating folder: ../data/ucf101/rawframes/BalanceBeam
# Creating folder: ../data/ucf101/rawframes/WallPushups
# Creating folder: ../data/ucf101/rawframes/MilitaryParade
# Creating folder: ../data/ucf101/rawframes/SkyDiving
# Creating folder: ../data/ucf101/rawframes/Rowing
# Creating folder: ../data/ucf101/rawframes/FrisbeeCatch
# Creating folder: ../data/ucf101/rawframes/SoccerPenalty
# Creating folder: ../data/ucf101/rawframes/UnevenBars
# Creating folder: ../data/ucf101/rawframes/PlayingDaf
# Creating folder: ../data/ucf101/rawframes/Lunges
# Creating folder: ../data/ucf101/rawframes/HorseRiding
# Creating folder: ../data/ucf101/rawframes/BoxingPunchingBag
# Creating folder: ../data/ucf101/rawframes/Skiing
# Creating folder: ../data/ucf101/rawframes/PlayingFlute
# Creating folder: ../data/ucf101/rawframes/CleanAndJerk
# Creating folder: ../data/ucf101/rawframes/GolfSwing
# Creating folder: ../data/ucf101/rawframes/FloorGymnastics
# Creating folder: ../data/ucf101/rawframes/JugglingBalls
# Creating folder: ../data/ucf101/rawframes/PushUps
# Creating folder: ../data/ucf101/rawframes/StillRings
# Creating folder: ../data/ucf101/rawframes/BodyWeightSquats
# Creating folder: ../data/ucf101/rawframes/CricketBowling
# Creating folder: ../data/ucf101/rawframes/HighJump
# Creating folder: ../data/ucf101/rawframes/HandstandPushups
# Creating folder: ../data/ucf101/rawframes/PoleVault
# Creating folder: ../data/ucf101/rawframes/CuttingInKitchen
# Creating folder: ../data/ucf101/rawframes/Skijet
# Creating folder: ../data/ucf101/rawframes/Surfing
# Creating folder: ../data/ucf101/rawframes/PizzaTossing
# Creating folder: ../data/ucf101/rawframes/Biking
# Creating folder: ../data/ucf101/rawframes/TennisSwing
# Creating folder: ../data/ucf101/rawframes/ApplyEyeMakeup
# Creating folder: ../data/ucf101/rawframes/FieldHockeyPenalty
# Creating folder: ../data/ucf101/rawframes/BandMarching
# Creating folder: ../data/ucf101/rawframes/BoxingSpeedBag
# Reading videos from folder:  ../data/ucf101/videos/
# Extension of videos:  avi
# Total number of videos found:  13320
# PlayingCello/v_PlayingCello_g04_c05 done with 125 frames
# SalsaSpin/v_SalsaSpin_g06_c03 done with 167 frames
# ShavingBeard/v_ShavingBeard_g13_c06 done with 173 frames
# PullUps/v_PullUps_g15_c02 done with 197 frames
# PlayingGuitar/v_PlayingGuitar_g17_c07 done with 250 frames
# PlayingCello/v_PlayingCello_g05_c07 done with 143 frames
# PullUps/v_PullUps_g22_c01 done with 106 frames
# PlayingDhol/v_PlayingDhol_g21_c02 done with 298 frames
# SalsaSpin/v_SalsaSpin_g09_c03 done with 167 frames
# PommelHorse/v_PommelHorse_g16_c04 done with 380 frames
# ShavingBeard/v_ShavingBeard_g06_c03 done with 188 frames
# SalsaSpin/v_SalsaSpin_g24_c05 done with 153 frames
# PullUps/v_PullUps_g21_c01 done with 165 frames
# PlayingGuitar/v_PlayingGuitar_g14_c04 done with 250 frames
# JumpRope/v_JumpRope_g13_c01 done with 539 frames
# ShavingBeard/v_ShavingBeard_g23_c04 done with 193 frames
# PlayingCello/v_PlayingCello_g17_c04 done with 318 frames
# PullUps/v_PullUps_g22_c03 done with 106 frames
# PommelHorse/v_PommelHorse_g18_c03 done with 227 frames
# PlayingDhol/v_PlayingDhol_g25_c01 done with 357 frames
# ShavingBeard/v_ShavingBeard_g03_c06 done with 149 frames
# PlayingGuitar/v_PlayingGuitar_g04_c05 done with 250 frames
# PlayingCello/v_PlayingCello_g06_c02 done with 225 frames
# PullUps/v_PullUps_g03_c01 done with 178 frames
# SalsaSpin/v_SalsaSpin_g04_c02 done with 333 frames
# PlayingDhol/v_PlayingDhol_g15_c04 done with 186 frames
# PommelHorse/v_PommelHorse_g21_c03 done with 301 frames
# JumpRope/v_JumpRope_g20_c07 done with 476 frames
# PullUps/v_PullUps_g18_c03 done with 161 frames
# ShavingBeard/v_ShavingBeard_g02_c07 done with 250 frames
# SalsaSpin/v_SalsaSpin_g15_c04 done with 167 frames
# PlayingGuitar/v_PlayingGuitar_g18_c07 done with 250 frames
# PlayingCello/v_PlayingCello_g13_c05 done with 222 frames
# JumpRope/v_JumpRope_g22_c01 done with 198 frames
# PommelHorse/v_PommelHorse_g03_c03 done with 251 frames
# PullUps/v_PullUps_g03_c02 done with 208 frames
# SalsaSpin/v_SalsaSpin_g18_c02 done with 168 frames
# PlayingDhol/v_PlayingDhol_g21_c06 done with 302 frames
# PlayingGuitar/v_PlayingGuitar_g20_c02 done with 250 frames
# PlayingCello/v_PlayingCello_g24_c05 done with 263 frames
# [Warning] length inconsistent!Early stop with 190 out of 190 frames
# PullUps/v_PullUps_g23_c02 done with 190 frames
# PullUps/v_PullUps_g14_c01 done with 79 frames
# PommelHorse/v_PommelHorse_g23_c04 done with 355 frames
# ShavingBeard/v_ShavingBeard_g05_c02 done with 507 frames
# JumpRope/v_JumpRope_g23_c04 done with 406 frames
# PlayingDhol/v_PlayingDhol_g14_c03 done with 291 frames
# SalsaSpin/v_SalsaSpin_g14_c05 done with 333 frames
# PlayingGuitar/v_PlayingGuitar_g07_c03 done with 250 frames
# PullUps/v_PullUps_g16_c02 done with 134 frames
# PlayingCello/v_PlayingCello_g20_c01 done with 322 frames
# SalsaSpin/v_SalsaSpin_g10_c04 done with 168 frames
# PlayingDhol/v_PlayingDhol_g12_c05 done with 241 frames
# PullUps/v_PullUps_g20_c02 done with 217 frames
# SalsaSpin/v_SalsaSpin_g06_c05 done with 167 frames
# PlayingGuitar/v_PlayingGuitar_g08_c03 done with 250 frames
# JumpRope/v_JumpRope_g24_c03 done with 411 frames
# PlayingCello/v_PlayingCello_g05_c05 done with 181 frames
# ShavingBeard/v_ShavingBeard_g07_c06 done with 386 frames
# PommelHorse/v_PommelHorse_g22_c01 done with 389 frames
# PullUps/v_PullUps_g06_c01 done with 84 frames
# SalsaSpin/v_SalsaSpin_g09_c01 done with 167 frames
# ShavingBeard/v_ShavingBeard_g24_c06 done with 203 frames
# PlayingDhol/v_PlayingDhol_g22_c05 done with 254 frames
# PlayingGuitar/v_PlayingGuitar_g22_c02 done with 250 frames
# PlayingCello/v_PlayingCello_g16_c02 done with 202 frames
# PullUps/v_PullUps_g24_c02 done with 192 frames
# SalsaSpin/v_SalsaSpin_g09_c04 done with 167 frames
# ShavingBeard/v_ShavingBeard_g09_c04 done with 136 frames
# PullUps/v_PullUps_g18_c01 done with 155 frames
# PommelHorse/v_PommelHorse_g01_c04 done with 357 frames
# JumpRope/v_JumpRope_g21_c02 done with 445 frames
# PlayingCello/v_PlayingCello_g21_c02 done with 232 frames
# ShavingBeard/v_ShavingBeard_g21_c01 done with 162 frames
# SalsaSpin/v_SalsaSpin_g05_c03 done with 200 frames
# PlayingGuitar/v_PlayingGuitar_g14_c02 done with 300 frames
# PlayingDhol/v_PlayingDhol_g06_c07 done with 357 frames
# PullUps/v_PullUps_g17_c02 done with 186 frames
# PullUps/v_PullUps_g11_c04 done with 100 frames
# SalsaSpin/v_SalsaSpin_g06_c04 done with 167 frames
# PommelHorse/v_PommelHorse_g12_c02 done with 333 frames
# JumpRope/v_JumpRope_g15_c02 done with 352 frames
# ShavingBeard/v_ShavingBeard_g14_c04 done with 222 frames
# PlayingCello/v_PlayingCello_g11_c02 done with 230 frames
# PullUps/v_PullUps_g25_c02 done with 110 frames
# PlayingGuitar/v_PlayingGuitar_g17_c05 done with 250 frames
# PullUps/v_PullUps_g12_c01 done with 82 frames
# SalsaSpin/v_SalsaSpin_g18_c03 done with 168 frames
# PommelHorse/v_PommelHorse_g09_c03 done with 253 frames
# PlayingCello/v_PlayingCello_g04_c02 done with 212 frames
# PlayingDhol/v_PlayingDhol_g04_c03 done with 452 frames
# ShavingBeard/v_ShavingBeard_g17_c02 done with 308 frames
# PlayingGuitar/v_PlayingGuitar_g17_c06 done with 250 frames
# SalsaSpin/v_SalsaSpin_g01_c07 done with 167 frames
# PullUps/v_PullUps_g24_c01 done with 154 frames
# JumpRope/v_JumpRope_g25_c05 done with 391 frames
# ShavingBeard/v_ShavingBeard_g09_c03 done with 201 frames
# PullUps/v_PullUps_g24_c04 done with 198 frames
# PlayingCello/v_PlayingCello_g24_c02 done with 335 frames
# PlayingDhol/v_PlayingDhol_g23_c04 done with 291 frames
# PlayingGuitar/v_PlayingGuitar_g07_c05 done with 250 frames
# ShavingBeard/v_ShavingBeard_g19_c03 done with 204 frames
# SalsaSpin/v_SalsaSpin_g02_c03 done with 333 frames
# PullUps/v_PullUps_g10_c03 done with 199 frames
# ShavingBeard/v_ShavingBeard_g09_c07 done with 292 frames
# PullUps/v_PullUps_g25_c04 done with 79 frames
# PlayingCello/v_PlayingCello_g08_c02 done with 214 frames
# PommelHorse/v_PommelHorse_g07_c07 done with 632 frames
# PlayingGuitar/v_PlayingGuitar_g08_c06 done with 250 frames
# PlayingDhol/v_PlayingDhol_g18_c03 done with 199 frames
# JumpRope/v_JumpRope_g11_c05 done with 495 frames
# SalsaSpin/v_SalsaSpin_g01_c02 done with 167 frames
# ShavingBeard/v_ShavingBeard_g01_c01 done with 127 frames
# PullUps/v_PullUps_g23_c04 done with 194 frames
# ShavingBeard/v_ShavingBeard_g24_c03 done with 93 frames
# PullUps/v_PullUps_g25_c01 done with 92 frames
# PlayingCello/v_PlayingCello_g01_c01 done with 223 frames
# PlayingGuitar/v_PlayingGuitar_g03_c07 done with 250 frames
# ShavingBeard/v_ShavingBeard_g01_c04 done with 91 frames
# SalsaSpin/v_SalsaSpin_g05_c05 done with 200 frames
# PlayingDhol/v_PlayingDhol_g05_c07 done with 272 frames
# PommelHorse/v_PommelHorse_g13_c06 done with 304 frames
# PullUps/v_PullUps_g09_c03 done with 105 frames
# JumpRope/v_JumpRope_g08_c06 done with 356 frames
# SalsaSpin/v_SalsaSpin_g15_c01 done with 167 frames
# ShavingBeard/v_ShavingBeard_g03_c07 done with 157 frames
# PlayingCello/v_PlayingCello_g01_c03 done with 162 frames
# PlayingGuitar/v_PlayingGuitar_g23_c01 done with 250 frames
# PullUps/v_PullUps_g17_c04 done with 226 frames
# PlayingDhol/v_PlayingDhol_g05_c02 done with 268 frames
# SalsaSpin/v_SalsaSpin_g10_c05 done with 168 frames
# PlayingCello/v_PlayingCello_g02_c07 done with 228 frames
# PullUps/v_PullUps_g01_c01 done with 167 frames
# ShavingBeard/v_ShavingBeard_g20_c07 done with 294 frames
# PlayingGuitar/v_PlayingGuitar_g06_c05 done with 250 frames
# JumpRope/v_JumpRope_g12_c05 done with 403 frames
# SalsaSpin/v_SalsaSpin_g01_c05 done with 167 frames
# PommelHorse/v_PommelHorse_g17_c05 done with 508 frames
# PullUps/v_PullUps_g22_c02 done with 105 frames
# PlayingDhol/v_PlayingDhol_g07_c07 done with 270 frames
# PullUps/v_PullUps_g19_c01 done with 111 frames
# SalsaSpin/v_SalsaSpin_g23_c03 done with 168 frames
# ShavingBeard/v_ShavingBeard_g22_c05 done with 207 frames
# PlayingGuitar/v_PlayingGuitar_g05_c03 done with 250 frames
# PlayingCello/v_PlayingCello_g17_c05 done with 345 frames
# PullUps/v_PullUps_g13_c03 done with 78 frames
# PommelHorse/v_PommelHorse_g18_c04 done with 278 frames
# JumpRope/v_JumpRope_g19_c03 done with 335 frames
# PlayingCello/v_PlayingCello_g02_c04 done with 162 frames
# PlayingDhol/v_PlayingDhol_g02_c05 done with 267 frames
# PullUps/v_PullUps_g02_c01 done with 122 frames
# ShavingBeard/v_ShavingBeard_g15_c01 done with 209 frames
# PlayingGuitar/v_PlayingGuitar_g22_c03 done with 250 frames
# PlayingCello/v_PlayingCello_g16_c07 done with 133 frames
# SalsaSpin/v_SalsaSpin_g22_c02 done with 333 frames
# [Warning] length inconsistent!Early stop with 189 out of 189 frames
# PullUps/v_PullUps_g20_c04 done with 189 frames
# PlayingViolin/v_PlayingViolin_g12_c02 done with 181 frames
# PommelHorse/v_PommelHorse_g13_c02 done with 305 frames
# PlayingDhol/v_PlayingDhol_g02_c03 done with 267 frames
# PullUps/v_PullUps_g08_c03 done with 104 frames
# PlayingGuitar/v_PlayingGuitar_g13_c05 done with 250 frames
# SalsaSpin/v_SalsaSpin_g17_c03 done with 168 frames
# PullUps/v_PullUps_g02_c03 done with 131 frames
# PlayingViolin/v_PlayingViolin_g24_c01 done with 191 frames
# PlayingCello/v_PlayingCello_g23_c06 done with 275 frames
# JumpRope/v_JumpRope_g09_c07 done with 491 frames
# PullUps/v_PullUps_g14_c03 done with 86 frames
# PlayingDhol/v_PlayingDhol_g24_c02 done with 262 frames
# SalsaSpin/v_SalsaSpin_g05_c04 done with 200 frames
# PullUps/v_PullUps_g08_c04 done with 106 frames
# PlayingViolin/v_PlayingViolin_g03_c01 done with 181 frames
# PlayingGuitar/v_PlayingGuitar_g12_c07 done with 250 frames
# PlayingCello/v_PlayingCello_g13_c02 done with 238 frames
# PullUps/v_PullUps_g13_c02 done with 82 frames
# SalsaSpin/v_SalsaSpin_g10_c06 done with 168 frames
# PommelHorse/v_PommelHorse_g22_c06 done with 454 frames
# JumpRope/v_JumpRope_g03_c02 done with 305 frames
# PlayingViolin/v_PlayingViolin_g05_c04 done with 184 frames
# PullUps/v_PullUps_g15_c01 done with 165 frames
# PlayingDhol/v_PlayingDhol_g17_c01 done with 295 frames
# PlayingGuitar/v_PlayingGuitar_g12_c05 done with 250 frames
# SalsaSpin/v_SalsaSpin_g17_c01 done with 168 frames
# PlayingViolin/v_PlayingViolin_g07_c02 done with 174 frames
# PommelHorse/v_PommelHorse_g15_c02 done with 253 frames
# PullUps/v_PullUps_g20_c01 done with 152 frames
# PlayingCello/v_PlayingCello_g17_c03 done with 365 frames
# PlayingViolin/v_PlayingViolin_g17_c04 done with 176 frames
# SalsaSpin/v_SalsaSpin_g11_c01 done with 167 frames
# PullUps/v_PullUps_g01_c03 done with 181 frames
# PlayingGuitar/v_PlayingGuitar_g06_c01 done with 250 frames
# PlayingViolin/v_PlayingViolin_g04_c02 done with 174 frames
# JumpRope/v_JumpRope_g08_c03 done with 526 frames
# PlayingCello/v_PlayingCello_g23_c04 done with 210 frames
# SalsaSpin/v_SalsaSpin_g18_c04 done with 168 frames
# PlayingDhol/v_PlayingDhol_g10_c02 done with 428 frames
# [Warning] length inconsistent!Early stop with 188 out of 188 frames
# PullUps/v_PullUps_g23_c03 done with 188 frames
# PommelHorse/v_PommelHorse_g07_c05 done with 387 frames
# PlayingGuitar/v_PlayingGuitar_g05_c05 done with 234 frames
# SalsaSpin/v_SalsaSpin_g12_c06 done with 200 frames
# PlayingViolin/v_PlayingViolin_g11_c01 done with 198 frames
# PullUps/v_PullUps_g21_c04 done with 193 frames
# PommelHorse/v_PommelHorse_g08_c02 done with 249 frames
# PlayingCello/v_PlayingCello_g08_c05 done with 282 frames
# JumpRope/v_JumpRope_g03_c04 done with 316 frames
# SalsaSpin/v_SalsaSpin_g05_c01 done with 200 frames
# PlayingGuitar/v_PlayingGuitar_g04_c03 done with 250 frames
# PullUps/v_PullUps_g16_c01 done with 132 frames
# PlayingViolin/v_PlayingViolin_g06_c01 done with 177 frames
# PlayingCello/v_PlayingCello_g04_c06 done with 129 frames
# PlayingDhol/v_PlayingDhol_g25_c06 done with 411 frames
# SalsaSpin/v_SalsaSpin_g11_c04 done with 167 frames
# PullUps/v_PullUps_g04_c02 done with 142 frames
# JumpRope/v_JumpRope_g01_c01 done with 257 frames
# PlayingViolin/v_PlayingViolin_g09_c04 done with 187 frames
# PlayingCello/v_PlayingCello_g21_c01 done with 215 frames
# PlayingGuitar/v_PlayingGuitar_g13_c04 done with 250 frames
# PullUps/v_PullUps_g21_c02 done with 177 frames
# SalsaSpin/v_SalsaSpin_g21_c04 done with 200 frames
# PlayingDhol/v_PlayingDhol_g16_c04 done with 203 frames
# PlayingViolin/v_PlayingViolin_g20_c02 done with 173 frames
# PullUps/v_PullUps_g19_c03 done with 108 frames
# PlayingCello/v_PlayingCello_g12_c03 done with 140 frames
# PommelHorse/v_PommelHorse_g17_c03 done with 523 frames
# PullUps/v_PullUps_g13_c04 done with 81 frames
# SalsaSpin/v_SalsaSpin_g21_c02 done with 200 frames
# PlayingGuitar/v_PlayingGuitar_g15_c06 done with 250 frames
# PullUps/v_PullUps_g12_c03 done with 69 frames
# PlayingViolin/v_PlayingViolin_g17_c01 done with 176 frames
# JumpRope/v_JumpRope_g07_c06 done with 403 frames
# PlayingDhol/v_PlayingDhol_g08_c04 done with 287 frames
# PullUps/v_PullUps_g04_c01 done with 141 frames
# SalsaSpin/v_SalsaSpin_g05_c06 done with 200 frames
# PlayingCello/v_PlayingCello_g17_c06 done with 318 frames
# PlayingViolin/v_PlayingViolin_g25_c02 done with 191 frames
# JumpRope/v_JumpRope_g22_c05 done with 189 frames
# PlayingGuitar/v_PlayingGuitar_g19_c01 done with 250 frames
# PullUps/v_PullUps_g16_c04 done with 144 frames
# PlayingCello/v_PlayingCello_g14_c01 done with 138 frames
# PommelHorse/v_PommelHorse_g17_c06 done with 481 frames
# PlayingViolin/v_PlayingViolin_g18_c03 done with 188 frames
# PlayingDhol/v_PlayingDhol_g02_c04 done with 275 frames
# PullUps/v_PullUps_g06_c04 done with 170 frames
# SalsaSpin/v_SalsaSpin_g14_c01 done with 333 frames
# PlayingGuitar/v_PlayingGuitar_g04_c07 done with 250 frames
# PlayingCello/v_PlayingCello_g23_c05 done with 180 frames
# PlayingViolin/v_PlayingViolin_g16_c02 done with 183 frames
# PlayingDhol/v_PlayingDhol_g07_c01 done with 258 frames
# PullUps/v_PullUps_g17_c03 done with 202 frames
# SalsaSpin/v_SalsaSpin_g03_c02 done with 168 frames
# JumpRope/v_JumpRope_g21_c04 done with 503 frames
# PlayingViolin/v_PlayingViolin_g06_c02 done with 176 frames
# PlayingCello/v_PlayingCello_g15_c07 done with 202 frames
# PlayingGuitar/v_PlayingGuitar_g13_c02 done with 250 frames
# PommelHorse/v_PommelHorse_g19_c05 done with 423 frames
# PullUps/v_PullUps_g09_c01 done with 107 frames
# SalsaSpin/v_SalsaSpin_g24_c03 done with 168 frames
# JumpRope/v_JumpRope_g22_c03 done with 212 frames
# PlayingDhol/v_PlayingDhol_g21_c04 done with 264 frames
# PlayingViolin/v_PlayingViolin_g04_c04 done with 176 frames
# PullUps/v_PullUps_g23_c01 done with 178 frames
# PlayingGuitar/v_PlayingGuitar_g09_c04 done with 250 frames
# SalsaSpin/v_SalsaSpin_g08_c03 done with 200 frames
# PlayingCello/v_PlayingCello_g23_c07 done with 267 frames
# PommelHorse/v_PommelHorse_g16_c02 done with 302 frames
# PlayingViolin/v_PlayingViolin_g25_c04 done with 175 frames
# PullUps/v_PullUps_g01_c02 done with 138 frames
# SalsaSpin/v_SalsaSpin_g24_c04 done with 168 frames
# PullUps/v_PullUps_g11_c01 done with 95 frames
# PlayingCello/v_PlayingCello_g19_c01 done with 197 frames
# PlayingGuitar/v_PlayingGuitar_g06_c02 done with 250 frames
# PlayingViolin/v_PlayingViolin_g20_c03 done with 170 frames
# PlayingDhol/v_PlayingDhol_g06_c02 done with 368 frames
# PommelHorse/v_PommelHorse_g11_c02 done with 251 frames
# SalsaSpin/v_SalsaSpin_g18_c01 done with 168 frames
# PullUps/v_PullUps_g02_c04 done with 178 frames
# PlayingViolin/v_PlayingViolin_g23_c02 done with 171 frames
# [Warning] length inconsistent!Early stop with 601 out of 601 frames
# JumpRope/v_JumpRope_g10_c02 done with 601 frames
# PlayingCello/v_PlayingCello_g15_c05 done with 202 frames
# PlayingGuitar/v_PlayingGuitar_g10_c01 done with 250 frames
# PullUps/v_PullUps_g22_c04 done with 144 frames
# SalsaSpin/v_SalsaSpin_g03_c03 done with 168 frames
# PlayingDhol/v_PlayingDhol_g08_c03 done with 297 frames
# PommelHorse/v_PommelHorse_g21_c01 done with 295 frames
# PullUps/v_PullUps_g05_c03 done with 108 frames
# PlayingViolin/v_PlayingViolin_g23_c03 done with 196 frames
# SalsaSpin/v_SalsaSpin_g23_c01 done with 168 frames
# PullUps/v_PullUps_g25_c03 done with 67 frames
# PlayingCello/v_PlayingCello_g15_c06 done with 268 frames
# PlayingGuitar/v_PlayingGuitar_g15_c04 done with 250 frames
# PlayingDhol/v_PlayingDhol_g21_c01 done with 247 frames
# PlayingViolin/v_PlayingViolin_g05_c01 done with 176 frames
# SalsaSpin/v_SalsaSpin_g15_c05 done with 167 frames
# PullUps/v_PullUps_g03_c03 done with 203 frames
# JumpRope/v_JumpRope_g09_c04 done with 510 frames
# PlayingViolin/v_PlayingViolin_g22_c03 done with 171 frames
# PullUps/v_PullUps_g12_c04 done with 79 frames
# PlayingGuitar/v_PlayingGuitar_g24_c01 done with 250 frames
# PlayingCello/v_PlayingCello_g20_c04 done with 276 frames
# PlayingDhol/v_PlayingDhol_g11_c06 done with 294 frames
# SalsaSpin/v_SalsaSpin_g21_c05 done with 200 frames
# PommelHorse/v_PommelHorse_g20_c07 done with 490 frames
# PullUps/v_PullUps_g10_c04 done with 102 frames
# PlayingViolin/v_PlayingViolin_g01_c04 done with 178 frames
# PullUps/v_PullUps_g06_c03 done with 98 frames
# PlayingCello/v_PlayingCello_g14_c03 done with 214 frames
# PlayingGuitar/v_PlayingGuitar_g14_c01 done with 250 frames
# PlayingViolin/v_PlayingViolin_g13_c01 done with 180 frames
# PullUps/v_PullUps_g10_c01 done with 142 frames
# PommelHorse/v_PommelHorse_g06_c04 done with 308 frames
# SalsaSpin/v_SalsaSpin_g25_c01 done with 333 frames
# PullUps/v_PullUps_g05_c04 done with 144 frames
# JumpRope/v_JumpRope_g18_c06 done with 599 frames
# PlayingDhol/v_PlayingDhol_g10_c01 done with 412 frames
# PlayingViolin/v_PlayingViolin_g10_c01 done with 174 frames
# PlayingGuitar/v_PlayingGuitar_g10_c06 done with 250 frames
# PullUps/v_PullUps_g19_c04 done with 104 frames
# PlayingCello/v_PlayingCello_g17_c02 done with 388 frames
# SalsaSpin/v_SalsaSpin_g02_c06 done with 333 frames
# PlayingDhol/v_PlayingDhol_g13_c06 done with 264 frames
# PlayingGuitar/v_PlayingGuitar_g14_c06 done with 250 frames
# PommelHorse/v_PommelHorse_g04_c05 done with 398 frames
# PullUps/v_PullUps_g21_c03 done with 183 frames
# JumpRope/v_JumpRope_g06_c04 done with 358 frames
# PullUps/v_PullUps_g19_c02 done with 102 frames
# SalsaSpin/v_SalsaSpin_g03_c05 done with 168 frames
# PlayingCello/v_PlayingCello_g09_c01 done with 309 frames
# PullUps/v_PullUps_g07_c04 done with 93 frames
# PlayingGuitar/v_PlayingGuitar_g07_c06 done with 250 frames
# PlayingViolin/v_PlayingViolin_g02_c03 done with 509 frames
# PlayingDhol/v_PlayingDhol_g02_c06 done with 289 frames
# [Warning] length inconsistent!Early stop with 93 out of 93 frames
# PullUps/v_PullUps_g07_c03 done with 93 frames
# JumpRope/v_JumpRope_g01_c02 done with 268 frames
# SalsaSpin/v_SalsaSpin_g21_c03 done with 200 frames
# PlayingCello/v_PlayingCello_g06_c06 done with 216 frames
# PullUps/v_PullUps_g14_c04 done with 86 frames
# PommelHorse/v_PommelHorse_g17_c02 done with 490 frames
# PlayingViolin/v_PlayingViolin_g09_c02 done with 176 frames
# PlayingCello/v_PlayingCello_g10_c01 done with 145 frames
# SalsaSpin/v_SalsaSpin_g17_c04 done with 168 frames
# PlayingGuitar/v_PlayingGuitar_g20_c04 done with 250 frames
# PullUps/v_PullUps_g07_c02 done with 128 frames
# PlayingViolin/v_PlayingViolin_g07_c04 done with 173 frames
# PullUps/v_PullUps_g09_c02 done with 101 frames
# JumpRope/v_JumpRope_g18_c01 done with 364 frames
# PlayingDhol/v_PlayingDhol_g25_c02 done with 353 frames
# PlayingCello/v_PlayingCello_g24_c04 done with 238 frames
# PullUps/v_PullUps_g13_c01 done with 93 frames
# PlayingGuitar/v_PlayingGuitar_g18_c02 done with 250 frames
# PlayingViolin/v_PlayingViolin_g22_c04 done with 170 frames
# SalsaSpin/v_SalsaSpin_g04_c05 done with 333 frames
# PommelHorse/v_PommelHorse_g19_c04 done with 394 frames
# PullUps/v_PullUps_g06_c02 done with 87 frames
# PlayingCello/v_PlayingCello_g16_c05 done with 195 frames
# PlayingDhol/v_PlayingDhol_g01_c05 done with 246 frames
# PlayingViolin/v_PlayingViolin_g12_c01 done with 215 frames
# PlayingGuitar/v_PlayingGuitar_g13_c03 done with 250 frames
# PullUps/v_PullUps_g10_c02 done with 173 frames
# PommelHorse/v_PommelHorse_g05_c03 done with 247 frames
# SalsaSpin/v_SalsaSpin_g22_c05 done with 333 frames
# PlayingCello/v_PlayingCello_g22_c04 done with 215 frames
# PlayingViolin/v_PlayingViolin_g03_c03 done with 181 frames
# JumpRope/v_JumpRope_g16_c01 done with 539 frames
# PullUps/v_PullUps_g20_c03 done with 197 frames
# PlayingGuitar/v_PlayingGuitar_g03_c05 done with 250 frames
# PlayingDhol/v_PlayingDhol_g05_c04 done with 297 frames
# PullUps/v_PullUps_g08_c02 done with 103 frames
# PlayingViolin/v_PlayingViolin_g12_c03 done with 197 frames
# PlayingCello/v_PlayingCello_g07_c03 done with 282 frames
# PullUps/v_PullUps_g09_c04 done with 99 frames
# PommelHorse/v_PommelHorse_g04_c01 done with 298 frames
# JumpRope/v_JumpRope_g23_c05 done with 242 frames
# SalsaSpin/v_SalsaSpin_g02_c02 done with 333 frames
# PlayingGuitar/v_PlayingGuitar_g03_c03 done with 250 frames
# PlayingViolin/v_PlayingViolin_g21_c02 done with 174 frames
# PullUps/v_PullUps_g04_c03 done with 154 frames
# PlayingDhol/v_PlayingDhol_g17_c04 done with 305 frames
# PullUps/v_PullUps_g12_c02 done with 73 frames
# PlayingCello/v_PlayingCello_g06_c03 done with 284 frames
# PlayingViolin/v_PlayingViolin_g15_c04 done with 168 frames
# PullUps/v_PullUps_g05_c02 done with 121 frames
# PlayingGuitar/v_PlayingGuitar_g08_c04 done with 250 frames
# SalsaSpin/v_SalsaSpin_g25_c03 done with 333 frames
# PommelHorse/v_PommelHorse_g14_c03 done with 357 frames
# PlayingViolin/v_PlayingViolin_g01_c01 done with 186 frames
# BenchPress/v_BenchPress_g11_c01 done with 98 frames
# JumpRope/v_JumpRope_g02_c01 done with 448 frames
# PlayingDhol/v_PlayingDhol_g13_c05 done with 277 frames
# PullUps/v_PullUps_g02_c02 done with 176 frames
# PlayingCello/v_PlayingCello_g07_c05 done with 272 frames
# BenchPress/v_BenchPress_g08_c07 done with 72 frames
# PullUps/v_PullUps_g07_c01 done with 98 frames
# PlayingGuitar/v_PlayingGuitar_g12_c06 done with 250 frames
# PlayingViolin/v_PlayingViolin_g06_c04 done with 187 frames
# BenchPress/v_BenchPress_g07_c07 done with 79 frames
# PullUps/v_PullUps_g04_c04 done with 138 frames
# PlayingCello/v_PlayingCello_g01_c02 done with 211 frames
# PlayingViolin/v_PlayingViolin_g19_c01 done with 204 frames
# PullUps/v_PullUps_g14_c02 done with 81 frames
# PlayingDhol/v_PlayingDhol_g17_c05 done with 302 frames
# BenchPress/v_BenchPress_g16_c04 done with 218 frames
# PommelHorse/v_PommelHorse_g12_c06 done with 444 frames
# PlayingGuitar/v_PlayingGuitar_g10_c04 done with 250 frames
# PullUps/v_PullUps_g11_c03 done with 91 frames
# BenchPress/v_BenchPress_g05_c05 done with 165 frames
# PlayingViolin/v_PlayingViolin_g24_c02 done with 178 frames
# PullUps/v_PullUps_g24_c03 done with 181 frames
# JumpRope/v_JumpRope_g04_c07 done with 518 frames
# BenchPress/v_BenchPress_g16_c05 done with 124 frames
# PlayingCello/v_PlayingCello_g15_c03 done with 302 frames
# BenchPress/v_BenchPress_g15_c01 done with 67 frames
# PommelHorse/v_PommelHorse_g04_c04 done with 298 frames
# PlayingGuitar/v_PlayingGuitar_g22_c04 done with 250 frames
# PlayingViolin/v_PlayingViolin_g21_c04 done with 174 frames
# PullUps/v_PullUps_g15_c03 done with 207 frames
# PlayingDhol/v_PlayingDhol_g25_c03 done with 365 frames
# BenchPress/v_BenchPress_g13_c01 done with 140 frames
# PlayingCello/v_PlayingCello_g20_c05 done with 241 frames
# PlayingViolin/v_PlayingViolin_g15_c02 done with 168 frames
# BenchPress/v_BenchPress_g06_c06 done with 96 frames
# PullUps/v_PullUps_g05_c01 done with 174 frames
# PlayingGuitar/v_PlayingGuitar_g22_c05 done with 250 frames
# BenchPress/v_BenchPress_g11_c03 done with 93 frames
# JumpRope/v_JumpRope_g06_c01 done with 387 frames
# PlayingCello/v_PlayingCello_g04_c04 done with 143 frames
# PlayingViolin/v_PlayingViolin_g16_c03 done with 171 frames
# BenchPress/v_BenchPress_g02_c06 done with 72 frames
# PullUps/v_PullUps_g17_c01 done with 164 frames
# PommelHorse/v_PommelHorse_g01_c01 done with 396 frames
# PlayingDhol/v_PlayingDhol_g06_c06 done with 364 frames
# BenchPress/v_BenchPress_g20_c03 done with 91 frames
# TrampolineJumping/v_TrampolineJumping_g18_c01 done with 201 frames
# PlayingGuitar/v_PlayingGuitar_g07_c04 done with 250 frames
# PlayingViolin/v_PlayingViolin_g15_c01 done with 141 frames
# BenchPress/v_BenchPress_g12_c01 done with 65 frames
# PullUps/v_PullUps_g15_c04 done with 192 frames
# BenchPress/v_BenchPress_g22_c07 done with 132 frames
# PlayingViolin/v_PlayingViolin_g10_c02 done with 174 frames
# PommelHorse/v_PommelHorse_g17_c01 done with 301 frames
# [Warning] length inconsistent!Early stop with 142 out of 142 frames
# PullUps/v_PullUps_g16_c03 done with 142 frames
# TrampolineJumping/v_TrampolineJumping_g01_c02 done with 240 frames
# PlayingGuitar/v_PlayingGuitar_g25_c02 done with 250 frames
# JumpRope/v_JumpRope_g11_c03 done with 495 frames
# BenchPress/v_BenchPress_g13_c07 done with 103 frames
# PullUps/v_PullUps_g08_c01 done with 96 frames
# PlayingViolin/v_PlayingViolin_g11_c04 done with 173 frames
# PlayingDhol/v_PlayingDhol_g10_c03 done with 425 frames
# BenchPress/v_BenchPress_g04_c05 done with 148 frames
# TrampolineJumping/v_TrampolineJumping_g02_c05 done with 240 frames
# PlayingGuitar/v_PlayingGuitar_g06_c06 done with 250 frames
# PlayingViolin/v_PlayingViolin_g03_c02 done with 181 frames
# PommelHorse/v_PommelHorse_g19_c06 done with 349 frames
# PullUps/v_PullUps_g03_c04 done with 249 frames
# JumpRope/v_JumpRope_g25_c02 done with 408 frames
# BenchPress/v_BenchPress_g02_c03 done with 221 frames
# PlayingViolin/v_PlayingViolin_g07_c03 done with 168 frames
# PullUps/v_PullUps_g18_c04 done with 163 frames
# TrampolineJumping/v_TrampolineJumping_g19_c05 done with 240 frames
# PlayingGuitar/v_PlayingGuitar_g12_c01 done with 250 frames
# BenchPress/v_BenchPress_g08_c03 done with 57 frames
# PlayingDhol/v_PlayingDhol_g09_c07 done with 360 frames
# PullUps/v_PullUps_g11_c02 done with 114 frames
# BenchPress/v_BenchPress_g10_c02 done with 108 frames
# PlayingViolin/v_PlayingViolin_g16_c01 done with 167 frames
# TrampolineJumping/v_TrampolineJumping_g05_c01 done with 151 frames
# BenchPress/v_BenchPress_g14_c01 done with 96 frames
# PlayingGuitar/v_PlayingGuitar_g15_c02 done with 250 frames
# PullUps/v_PullUps_g01_c04 done with 157 frames
# PommelHorse/v_PommelHorse_g07_c04 done with 457 frames
# PlayingDhol/v_PlayingDhol_g07_c05 done with 277 frames
# JumpRope/v_JumpRope_g13_c04 done with 374 frames
# PlayingViolin/v_PlayingViolin_g11_c03 done with 190 frames
# TrampolineJumping/v_TrampolineJumping_g02_c01 done with 201 frames
# BenchPress/v_BenchPress_g13_c05 done with 141 frames
# PullUps/v_PullUps_g18_c02 done with 164 frames
# BenchPress/v_BenchPress_g17_c06 done with 117 frames
# PlayingViolin/v_PlayingViolin_g06_c03 done with 177 frames
# PlayingGuitar/v_PlayingGuitar_g21_c03 done with 250 frames
# TrampolineJumping/v_TrampolineJumping_g14_c04 done with 201 frames
# FrontCrawl/v_FrontCrawl_g16_c02 done with 126 frames
# BenchPress/v_BenchPress_g07_c01 done with 73 frames
# BenchPress/v_BenchPress_g02_c07 done with 78 frames
# PlayingDhol/v_PlayingDhol_g03_c03 done with 407 frames
# PlayingViolin/v_PlayingViolin_g04_c01 done with 176 frames
# TrampolineJumping/v_TrampolineJumping_g10_c01 done with 201 frames
# BenchPress/v_BenchPress_g22_c03 done with 74 frames
# PlayingGuitar/v_PlayingGuitar_g01_c04 done with 250 frames
# PommelHorse/v_PommelHorse_g22_c07 done with 497 frames
# JumpRope/v_JumpRope_g02_c05 done with 501 frames
# BenchPress/v_BenchPress_g12_c04 done with 103 frames
# PlayingViolin/v_PlayingViolin_g04_c03 done with 169 frames
# TrampolineJumping/v_TrampolineJumping_g11_c01 done with 201 frames
# FrontCrawl/v_FrontCrawl_g11_c07 done with 351 frames
# [Warning] length inconsistent!Early stop with 250 out of 250 frames
# PlayingGuitar/v_PlayingGuitar_g19_c05 done with 250 frames
# TrampolineJumping/v_TrampolineJumping_g19_c03 done with 106 frames
# PlayingDhol/v_PlayingDhol_g06_c04 done with 372 frames
# PlayingViolin/v_PlayingViolin_g19_c03 done with 224 frames
# PommelHorse/v_PommelHorse_g19_c01 done with 307 frames
# FrontCrawl/v_FrontCrawl_g22_c06 done with 138 frames
# BenchPress/v_BenchPress_g18_c03 done with 274 frames
# FrontCrawl/v_FrontCrawl_g10_c04 done with 114 frames
# PlayingGuitar/v_PlayingGuitar_g17_c01 done with 250 frames
# JumpRope/v_JumpRope_g19_c04 done with 476 frames
# TrampolineJumping/v_TrampolineJumping_g17_c03 done with 201 frames
# PlayingViolin/v_PlayingViolin_g05_c02 done with 176 frames
# BenchPress/v_BenchPress_g18_c05 done with 112 frames
# FrontCrawl/v_FrontCrawl_g18_c04 done with 104 frames
# PlayingDhol/v_PlayingDhol_g08_c02 done with 283 frames
# BenchPress/v_BenchPress_g09_c01 done with 85 frames
# PommelHorse/v_PommelHorse_g02_c01 done with 317 frames
# PlayingViolin/v_PlayingViolin_g22_c01 done with 170 frames
# FrontCrawl/v_FrontCrawl_g18_c01 done with 101 frames
# TrampolineJumping/v_TrampolineJumping_g19_c06 done with 240 frames
# PlayingGuitar/v_PlayingGuitar_g06_c04 done with 250 frames
# BenchPress/v_BenchPress_g21_c01 done with 188 frames
# JumpRope/v_JumpRope_g24_c06 done with 384 frames
# PlayingViolin/v_PlayingViolin_g10_c04 done with 173 frames
# BenchPress/v_BenchPress_g08_c04 done with 60 frames
# PlayingDhol/v_PlayingDhol_g11_c05 done with 280 frames
# PommelHorse/v_PommelHorse_g16_c01 done with 299 frames
# TrampolineJumping/v_TrampolineJumping_g20_c02 done with 201 frames
# FrontCrawl/v_FrontCrawl_g22_c02 done with 240 frames
# BenchPress/v_BenchPress_g19_c01 done with 92 frames
# PlayingGuitar/v_PlayingGuitar_g20_c05 done with 250 frames
# PlayingViolin/v_PlayingViolin_g02_c04 done with 180 frames
# BenchPress/v_BenchPress_g03_c06 done with 83 frames
# FrontCrawl/v_FrontCrawl_g14_c01 done with 149 frames
# TrampolineJumping/v_TrampolineJumping_g18_c03 done with 201 frames
# BenchPress/v_BenchPress_g18_c07 done with 78 frames
# PlayingDhol/v_PlayingDhol_g11_c07 done with 255 frames
# PommelHorse/v_PommelHorse_g23_c02 done with 252 frames
# FrontCrawl/v_FrontCrawl_g08_c04 done with 125 frames
# PlayingGuitar/v_PlayingGuitar_g08_c07 done with 250 frames
# PlayingViolin/v_PlayingViolin_g09_c03 done with 175 frames
# JumpRope/v_JumpRope_g18_c07 done with 405 frames
# TrampolineJumping/v_TrampolineJumping_g23_c03 done with 151 frames
# BenchPress/v_BenchPress_g18_c04 done with 127 frames
# FrontCrawl/v_FrontCrawl_g15_c01 done with 75 frames
# PlayingViolin/v_PlayingViolin_g20_c01 done with 167 frames
# FrontCrawl/v_FrontCrawl_g25_c04 done with 99 frames
# BenchPress/v_BenchPress_g10_c04 done with 134 frames
# PlayingDhol/v_PlayingDhol_g14_c05 done with 289 frames
# TrampolineJumping/v_TrampolineJumping_g16_c02 done with 171 frames
# PommelHorse/v_PommelHorse_g24_c01 done with 318 frames
# PlayingGuitar/v_PlayingGuitar_g01_c05 done with 238 frames
# BenchPress/v_BenchPress_g13_c02 done with 93 frames
# PlayingViolin/v_PlayingViolin_g03_c04 done with 199 frames
# TrampolineJumping/v_TrampolineJumping_g22_c04 done with 180 frames
# BenchPress/v_BenchPress_g25_c02 done with 108 frames
# JumpRope/v_JumpRope_g06_c02 done with 378 frames
# PommelHorse/v_PommelHorse_g16_c03 done with 202 frames
# PlayingDhol/v_PlayingDhol_g01_c02 done with 240 frames
# PlayingGuitar/v_PlayingGuitar_g18_c04 done with 250 frames
# FrontCrawl/v_FrontCrawl_g23_c01 done with 278 frames
# PlayingViolin/v_PlayingViolin_g23_c01 done with 180 frames
# TrampolineJumping/v_TrampolineJumping_g13_c02 done with 187 frames
# BenchPress/v_BenchPress_g25_c05 done with 222 frames
# PommelHorse/v_PommelHorse_g08_c01 done with 256 frames
# JumpRope/v_JumpRope_g19_c01 done with 307 frames
# PlayingGuitar/v_PlayingGuitar_g11_c07 done with 250 frames
# PlayingDhol/v_PlayingDhol_g12_c01 done with 312 frames
# BenchPress/v_BenchPress_g07_c06 done with 87 frames
# PlayingViolin/v_PlayingViolin_g13_c02 done with 171 frames
# TrampolineJumping/v_TrampolineJumping_g09_c03 done with 201 frames
# FrontCrawl/v_FrontCrawl_g23_c06 done with 350 frames
# BenchPress/v_BenchPress_g03_c01 done with 93 frames
# PlayingViolin/v_PlayingViolin_g13_c04 done with 171 frames
# TrampolineJumping/v_TrampolineJumping_g19_c04 done with 106 frames
# BenchPress/v_BenchPress_g14_c02 done with 99 frames
# PommelHorse/v_PommelHorse_g08_c03 done with 248 frames
# PlayingGuitar/v_PlayingGuitar_g15_c03 done with 250 frames
# FrontCrawl/v_FrontCrawl_g21_c05 done with 126 frames
# PlayingDhol/v_PlayingDhol_g22_c01 done with 250 frames
# PlayingViolin/v_PlayingViolin_g07_c01 done with 178 frames
# BenchPress/v_BenchPress_g10_c01 done with 112 frames
# JumpRope/v_JumpRope_g15_c04 done with 489 frames
# [Warning] length inconsistent!Early stop with 190 out of 192 frames
# TrampolineJumping/v_TrampolineJumping_g09_c06 done with 192 frames
# FrontCrawl/v_FrontCrawl_g03_c05 done with 193 frames
# PlayingViolin/v_PlayingViolin_g14_c04 done with 176 frames
# PlayingGuitar/v_PlayingGuitar_g05_c01 done with 250 frames
# FrontCrawl/v_FrontCrawl_g10_c05 done with 119 frames
# BenchPress/v_BenchPress_g09_c06 done with 211 frames
# PlayingDhol/v_PlayingDhol_g24_c04 done with 274 frames
# TrampolineJumping/v_TrampolineJumping_g18_c02 done with 151 frames
# PommelHorse/v_PommelHorse_g05_c04 done with 294 frames
# PlayingViolin/v_PlayingViolin_g19_c04 done with 204 frames
# FrontCrawl/v_FrontCrawl_g16_c01 done with 125 frames
# PlayingGuitar/v_PlayingGuitar_g03_c02 done with 250 frames
# BenchPress/v_BenchPress_g05_c06 done with 195 frames
# TrampolineJumping/v_TrampolineJumping_g10_c04 done with 201 frames
# FrontCrawl/v_FrontCrawl_g06_c04 done with 126 frames
# PlayingViolin/v_PlayingViolin_g23_c04 done with 188 frames
# PlayingDhol/v_PlayingDhol_g24_c01 done with 267 frames
# BenchPress/v_BenchPress_g12_c05 done with 84 frames
# JumpRope/v_JumpRope_g02_c03 done with 492 frames
# BenchPress/v_BenchPress_g05_c02 done with 67 frames
# PommelHorse/v_PommelHorse_g12_c01 done with 346 frames
# FrontCrawl/v_FrontCrawl_g06_c05 done with 143 frames
# PlayingGuitar/v_PlayingGuitar_g15_c07 done with 250 frames
# TrampolineJumping/v_TrampolineJumping_g07_c05 done with 240 frames
# PlayingViolin/v_PlayingViolin_g19_c02 done with 204 frames
# BenchPress/v_BenchPress_g09_c05 done with 63 frames
# BenchPress/v_BenchPress_g03_c04 done with 105 frames
# JumpRope/v_JumpRope_g22_c06 done with 221 frames
# PlayingDhol/v_PlayingDhol_g22_c06 done with 255 frames
# PlayingViolin/v_PlayingViolin_g24_c04 done with 177 frames
# TrampolineJumping/v_TrampolineJumping_g13_c01 done with 187 frames
# BenchPress/v_BenchPress_g11_c05 done with 114 frames
# PlayingGuitar/v_PlayingGuitar_g16_c05 done with 250 frames
# FrontCrawl/v_FrontCrawl_g04_c02 done with 262 frames
# PommelHorse/v_PommelHorse_g21_c02 done with 302 frames
# BenchPress/v_BenchPress_g22_c04 done with 71 frames
# PlayingViolin/v_PlayingViolin_g08_c04 done with 181 frames
# BenchPress/v_BenchPress_g11_c02 done with 95 frames
# FrontCrawl/v_FrontCrawl_g17_c07 done with 150 frames
# PlayingDhol/v_PlayingDhol_g01_c04 done with 239 frames
# PlayingGuitar/v_PlayingGuitar_g12_c03 done with 250 frames
# FrontCrawl/v_FrontCrawl_g10_c02 done with 129 frames
# TrampolineJumping/v_TrampolineJumping_g11_c05 done with 306 frames
# PlayingViolin/v_PlayingViolin_g14_c02 done with 169 frames
# BenchPress/v_BenchPress_g23_c03 done with 176 frames
# FrontCrawl/v_FrontCrawl_g21_c01 done with 170 frames
# BenchPress/v_BenchPress_g24_c05 done with 111 frames
# TrampolineJumping/v_TrampolineJumping_g10_c03 done with 201 frames
# PlayingDhol/v_PlayingDhol_g05_c06 done with 295 frames
# PlayingViolin/v_PlayingViolin_g11_c02 done with 190 frames
# [Warning] length inconsistent!Early stop with 615 out of 623 frames
# JumpRope/v_JumpRope_g17_c01 done with 623 frames
# PlayingGuitar/v_PlayingGuitar_g13_c07 done with 250 frames
# FrontCrawl/v_FrontCrawl_g19_c02 done with 80 frames
# BenchPress/v_BenchPress_g24_c06 done with 80 frames
# TrampolineJumping/v_TrampolineJumping_g21_c02 done with 201 frames
# [Warning] length inconsistent!Early stop with 670 out of 670 frames
# PommelHorse/v_PommelHorse_g07_c06 done with 670 frames
# PlayingViolin/v_PlayingViolin_g25_c03 done with 201 frames
# FrontCrawl/v_FrontCrawl_g07_c03 done with 182 frames
# PlayingGuitar/v_PlayingGuitar_g16_c07 done with 250 frames
# PlayingDhol/v_PlayingDhol_g17_c02 done with 297 frames
# BenchPress/v_BenchPress_g11_c04 done with 251 frames
# BenchPress/v_BenchPress_g07_c03 done with 72 frames
# TrampolineJumping/v_TrampolineJumping_g10_c02 done with 201 frames
# PlayingViolin/v_PlayingViolin_g21_c01 done with 183 frames
# JumpRope/v_JumpRope_g13_c05 done with 391 frames
# FrontCrawl/v_FrontCrawl_g20_c05 done with 223 frames
# PommelHorse/v_PommelHorse_g06_c03 done with 301 frames
# PlayingGuitar/v_PlayingGuitar_g15_c01 done with 250 frames
# TrampolineJumping/v_TrampolineJumping_g23_c01 done with 151 frames
# FrontCrawl/v_FrontCrawl_g17_c01 done with 155 frames
# PlayingDhol/v_PlayingDhol_g23_c03 done with 295 frames
# BenchPress/v_BenchPress_g22_c06 done with 274 frames
# PlayingViolin/v_PlayingViolin_g02_c02 done with 339 frames
# PlayingGuitar/v_PlayingGuitar_g04_c02 done with 250 frames
# FrontCrawl/v_FrontCrawl_g09_c06 done with 128 frames
# PommelHorse/v_PommelHorse_g25_c03 done with 328 frames
# BenchPress/v_BenchPress_g25_c06 done with 123 frames
# PlayingViolin/v_PlayingViolin_g14_c01 done with 161 frames
# [Warning] length inconsistent!Early stop with 328 out of 330 frames
# TrampolineJumping/v_TrampolineJumping_g06_c04 done with 330 frames
# JumpRope/v_JumpRope_g15_c05 done with 531 frames
# BenchPress/v_BenchPress_g23_c02 done with 126 frames
# FrontCrawl/v_FrontCrawl_g17_c02 done with 152 frames
# PlayingViolin/v_PlayingViolin_g17_c02 done with 185 frames
# PlayingGuitar/v_PlayingGuitar_g21_c05 done with 250 frames
# PlayingDhol/v_PlayingDhol_g09_c04 done with 326 frames
# TrampolineJumping/v_TrampolineJumping_g09_c02 done with 201 frames
# FrontCrawl/v_FrontCrawl_g21_c06 done with 112 frames
# PlayingViolin/v_PlayingViolin_g20_c04 done with 179 frames
# BenchPress/v_BenchPress_g20_c04 done with 210 frames
# FrontCrawl/v_FrontCrawl_g10_c01 done with 129 frames
# TrampolineJumping/v_TrampolineJumping_g12_c04 done with 180 frames
# BenchPress/v_BenchPress_g02_c01 done with 81 frames
# PlayingGuitar/v_PlayingGuitar_g23_c07 done with 250 frames
# FrontCrawl/v_FrontCrawl_g25_c02 done with 100 frames
# PlayingDhol/v_PlayingDhol_g14_c06 done with 276 frames
# PlayingViolin/v_PlayingViolin_g12_c04 done with 171 frames
# BenchPress/v_BenchPress_g06_c03 done with 65 frames
# PommelHorse/v_PommelHorse_g12_c05 done with 572 frames
# TrampolineJumping/v_TrampolineJumping_g12_c05 done with 180 frames
# FrontCrawl/v_FrontCrawl_g21_c03 done with 132 frames
# [Warning] length inconsistent!Early stop with 618 out of 618 frames
# JumpRope/v_JumpRope_g05_c03 done with 618 frames
# BenchPress/v_BenchPress_g06_c05 done with 128 frames
# PlayingViolin/v_PlayingViolin_g21_c03 done with 173 frames
# PlayingGuitar/v_PlayingGuitar_g19_c07 done with 250 frames
# BenchPress/v_BenchPress_g08_c02 done with 61 frames
# FrontCrawl/v_FrontCrawl_g09_c02 done with 100 frames
# PlayingDhol/v_PlayingDhol_g01_c01 done with 252 frames
# TrampolineJumping/v_TrampolineJumping_g08_c01 done with 180 frames
# FrontCrawl/v_FrontCrawl_g09_c01 done with 106 frames
# BenchPress/v_BenchPress_g01_c04 done with 105 frames
# PlayingViolin/v_PlayingViolin_g14_c03 done with 172 frames
# PommelHorse/v_PommelHorse_g11_c03 done with 248 frames
# BenchPress/v_BenchPress_g12_c02 done with 63 frames
# TrampolineJumping/v_TrampolineJumping_g15_c04 done with 151 frames
# PlayingGuitar/v_PlayingGuitar_g09_c01 done with 250 frames
# BenchPress/v_BenchPress_g15_c03 done with 72 frames
# PlayingViolin/v_PlayingViolin_g01_c03 done with 170 frames
# FrontCrawl/v_FrontCrawl_g20_c03 done with 233 frames
# PommelHorse/v_PommelHorse_g03_c04 done with 239 frames
# PlayingDhol/v_PlayingDhol_g03_c01 done with 357 frames
# JumpRope/v_JumpRope_g20_c06 done with 526 frames
# BenchPress/v_BenchPress_g14_c06 done with 178 frames
# PlayingGuitar/v_PlayingGuitar_g23_c06 done with 250 frames
# PlayingViolin/v_PlayingViolin_g24_c03 done with 191 frames
# BenchPress/v_BenchPress_g02_c04 done with 95 frames
# TrampolineJumping/v_TrampolineJumping_g08_c04 done with 296 frames
# FrontCrawl/v_FrontCrawl_g23_c05 done with 215 frames
# BenchPress/v_BenchPress_g13_c06 done with 102 frames
# PlayingViolin/v_PlayingViolin_g13_c03 done with 172 frames
# PommelHorse/v_PommelHorse_g04_c03 done with 308 frames
# PlayingDhol/v_PlayingDhol_g17_c06 done with 302 frames
# BenchPress/v_BenchPress_g16_c03 done with 100 frames
# PlayingGuitar/v_PlayingGuitar_g02_c03 done with 250 frames
# FrontCrawl/v_FrontCrawl_g23_c07 done with 230 frames
# TrampolineJumping/v_TrampolineJumping_g04_c04 done with 250 frames
# BenchPress/v_BenchPress_g09_c03 done with 69 frames
# JumpRope/v_JumpRope_g25_c01 done with 400 frames
# PlayingViolin/v_PlayingViolin_g02_c01 done with 169 frames
# BenchPress/v_BenchPress_g09_c04 done with 68 frames
# FrontCrawl/v_FrontCrawl_g09_c04 done with 117 frames
# TrampolineJumping/v_TrampolineJumping_g05_c02 done with 151 frames
# PlayingGuitar/v_PlayingGuitar_g01_c06 done with 250 frames
# PommelHorse/v_PommelHorse_g01_c06 done with 308 frames
# PlayingViolin/v_PlayingViolin_g09_c01 done with 170 frames
# BenchPress/v_BenchPress_g18_c06 done with 110 frames
# JumpRope/v_JumpRope_g22_c04 done with 246 frames
# PlayingDhol/v_PlayingDhol_g05_c05 done with 303 frames
# BenchPress/v_BenchPress_g06_c07 done with 84 frames
# FrontCrawl/v_FrontCrawl_g14_c05 done with 200 frames
# TrampolineJumping/v_TrampolineJumping_g13_c03 done with 187 frames
# PlayingViolin/v_PlayingViolin_g15_c03 done with 168 frames
# BenchPress/v_BenchPress_g05_c01 done with 74 frames
# PlayingGuitar/v_PlayingGuitar_g22_c01 done with 250 frames
# FrontCrawl/v_FrontCrawl_g24_c05 done with 124 frames
# BenchPress/v_BenchPress_g20_c05 done with 90 frames
# TrampolineJumping/v_TrampolineJumping_g11_c02 done with 151 frames
# BenchPress/v_BenchPress_g05_c07 done with 64 frames
# PommelHorse/v_PommelHorse_g11_c04 done with 294 frames
# PlayingViolin/v_PlayingViolin_g08_c01 done with 191 frames
# PlayingDhol/v_PlayingDhol_g12_c02 done with 320 frames
# FrontCrawl/v_FrontCrawl_g14_c06 done with 134 frames
# BenchPress/v_BenchPress_g03_c07 done with 85 frames
# PlayingGuitar/v_PlayingGuitar_g25_c03 done with 250 frames
# FrontCrawl/v_FrontCrawl_g19_c01 done with 87 frames
# PlayingViolin/v_PlayingViolin_g01_c02 done with 169 frames
# TrampolineJumping/v_TrampolineJumping_g06_c01 done with 201 frames
# BenchPress/v_BenchPress_g23_c01 done with 131 frames
# JumpRope/v_JumpRope_g16_c06 done with 529 frames
# PommelHorse/v_PommelHorse_g06_c01 done with 301 frames
# FrontCrawl/v_FrontCrawl_g20_c04 done with 213 frames
# PlayingViolin/v_PlayingViolin_g25_c01 done with 192 frames
# PlayingGuitar/v_PlayingGuitar_g02_c01 done with 250 frames
# TrampolineJumping/v_TrampolineJumping_g08_c03 done with 217 frames
# BenchPress/v_BenchPress_g19_c04 done with 249 frames
# BenchPress/v_BenchPress_g04_c02 done with 70 frames
# PlayingViolin/v_PlayingViolin_g05_c03 done with 169 frames
# PlayingDhol/v_PlayingDhol_g10_c07 done with 467 frames
# PommelHorse/v_PommelHorse_g02_c02 done with 312 frames
# BenchPress/v_BenchPress_g19_c03 done with 82 frames
# TrampolineJumping/v_TrampolineJumping_g09_c04 done with 201 frames
# PlayingGuitar/v_PlayingGuitar_g06_c07 done with 250 frames
# BenchPress/v_BenchPress_g24_c07 done with 74 frames
# PlayingViolin/v_PlayingViolin_g08_c02 done with 184 frames
# FrontCrawl/v_FrontCrawl_g04_c05 done with 392 frames
# JumpRope/v_JumpRope_g20_c02 done with 527 frames
# PommelHorse/v_PommelHorse_g15_c01 done with 252 frames
# TrampolineJumping/v_TrampolineJumping_g04_c02 done with 250 frames
# ...
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c05 done with 204 frames
# Biking/v_Biking_g05_c06 done with 180 frames
# BandMarching/v_BandMarching_g19_c06 done with 378 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c03 done with 210 frames
# Biking/v_Biking_g12_c03 done with 201 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c04 done with 138 frames
# BandMarching/v_BandMarching_g24_c06 done with 256 frames
# Biking/v_Biking_g17_c01 done with 152 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g07_c06 done with 162 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c01 done with 185 frames
# BandMarching/v_BandMarching_g03_c07 done with 249 frames
# Biking/v_Biking_g04_c03 done with 240 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c03 done with 94 frames
# BandMarching/v_BandMarching_g07_c01 done with 70 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g10_c02 done with 98 frames
# Biking/v_Biking_g02_c03 done with 240 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c02 done with 129 frames
# BandMarching/v_BandMarching_g23_c03 done with 262 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c03 done with 125 frames
# Biking/v_Biking_g24_c03 done with 167 frames
# BandMarching/v_BandMarching_g23_c06 done with 165 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c07 done with 145 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g23_c04 done with 223 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g24_c07 done with 194 frames
# Biking/v_Biking_g03_c02 done with 380 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g02_c01 done with 171 frames
# [Warning] length inconsistent!Early stop with 201 out of 201 frames
# Biking/v_Biking_g05_c03 done with 201 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c01 done with 209 frames
# Biking/v_Biking_g13_c01 done with 151 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g22_c05 done with 243 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c07 done with 452 frames
# Biking/v_Biking_g24_c07 done with 180 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g20_c04 done with 220 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c06 done with 122 frames
# Biking/v_Biking_g17_c06 done with 240 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c02 done with 446 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g20_c05 done with 113 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g24_c01 done with 112 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c04 done with 200 frames
# Biking/v_Biking_g20_c06 done with 358 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c04 done with 170 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c05 done with 160 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c05 done with 453 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c01 done with 120 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g10_c01 done with 125 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c04 done with 186 frames
# [Warning] length inconsistent!Early stop with 536 out of 536 frames
# Biking/v_Biking_g23_c01 done with 536 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c03 done with 209 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c01 done with 176 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g10_c02 done with 133 frames
# Biking/v_Biking_g06_c05 done with 201 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g18_c02 done with 170 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c06 done with 150 frames
# Biking/v_Biking_g12_c02 done with 203 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g12_c06 done with 212 frames
# Biking/v_Biking_g25_c01 done with 151 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c06 done with 115 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c01 done with 237 frames
# Biking/v_Biking_g05_c07 done with 180 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g06_c07 done with 167 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c02 done with 168 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g13_c06 done with 137 frames
# Biking/v_Biking_g08_c05 done with 240 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g13_c05 done with 119 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g20_c01 done with 290 frames
# Biking/v_Biking_g09_c02 done with 180 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c02 done with 258 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c03 done with 125 frames
# [Warning] length inconsistent!Early stop with 340 out of 345 frames
# Biking/v_Biking_g22_c03 done with 345 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c01 done with 426 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c03 done with 125 frames
# Biking/v_Biking_g07_c05 done with 192 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g18_c03 done with 157 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g21_c03 done with 164 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g13_c04 done with 120 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c02 done with 178 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c01 done with 164 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c02 done with 504 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c06 done with 140 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g19_c03 done with 126 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c04 done with 203 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c01 done with 116 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c02 done with 132 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g18_c04 done with 219 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c03 done with 115 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g20_c03 done with 130 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c06 done with 252 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c01 done with 111 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c04 done with 191 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c01 done with 112 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g01_c01 done with 131 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g15_c05 done with 259 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g21_c03 done with 127 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c05 done with 246 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g18_c01 done with 159 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c02 done with 134 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c04 done with 462 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c03 done with 259 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g19_c04 done with 126 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g20_c02 done with 158 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g16_c04 done with 98 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c05 done with 93 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g12_c02 done with 303 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c06 done with 152 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g05_c03 done with 190 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c02 done with 186 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c01 done with 170 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c03 done with 243 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c01 done with 191 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c07 done with 261 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g10_c01 done with 153 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g20_c05 done with 305 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c03 done with 146 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c02 done with 146 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g18_c02 done with 250 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c01 done with 126 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g05_c01 done with 135 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c06 done with 109 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g19_c05 done with 124 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g06_c06 done with 146 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g10_c03 done with 125 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c01 done with 135 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g21_c01 done with 125 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c05 done with 182 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c01 done with 139 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g24_c02 done with 105 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g24_c02 done with 127 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c04 done with 132 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c07 done with 235 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c04 done with 475 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g16_c02 done with 233 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g01_c04 done with 71 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c05 done with 180 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g08_c05 done with 226 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g07_c01 done with 158 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g03_c04 done with 147 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g19_c04 done with 131 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g05_c05 done with 183 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g22_c01 done with 170 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c02 done with 131 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c06 done with 243 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g15_c03 done with 232 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c01 done with 268 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c01 done with 402 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c01 done with 140 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g03_c03 done with 132 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c06 done with 248 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g12_c04 done with 250 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g21_c05 done with 90 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c05 done with 106 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g24_c03 done with 102 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c03 done with 298 frames
# ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c03 done with 114 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g20_c03 done with 114 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g12_c05 done with 204 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g23_c04 done with 84 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g05_c04 done with 136 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g06_c05 done with 128 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c02 done with 275 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g14_c04 done with 286 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g14_c01 done with 150 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g06_c04 done with 223 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g12_c06 done with 120 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g02_c01 done with 105 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g16_c01 done with 186 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c03 done with 437 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g04_c03 done with 82 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g05_c03 done with 112 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g23_c03 done with 243 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g10_c01 done with 186 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g08_c02 done with 243 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g11_c04 done with 217 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g05_c02 done with 164 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g17_c04 done with 83 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g03_c02 done with 82 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g16_c04 done with 145 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g15_c02 done with 97 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g23_c01 done with 254 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g24_c03 done with 94 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g12_c03 done with 245 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g24_c01 done with 114 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g06_c02 done with 244 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g25_c03 done with 123 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g25_c06 done with 75 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g05_c02 done with 77 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g12_c01 done with 121 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c06 done with 313 frames
# FieldHockeyPenalty/v_FieldHockeyPenalty_g24_c03 done with 105 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c03 done with 451 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g01_c03 done with 99 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g08_c04 done with 243 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g12_c03 done with 315 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g03_c01 done with 120 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g16_c03 done with 77 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g01_c02 done with 124 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c06 done with 233 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c07 done with 380 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g03_c05 done with 153 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c02 done with 193 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c05 done with 479 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c06 done with 437 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g22_c04 done with 214 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g02_c03 done with 178 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g21_c02 done with 164 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g02_c02 done with 199 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c03 done with 230 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g16_c01 done with 100 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c03 done with 233 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c07 done with 334 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c03 done with 251 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c05 done with 346 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c07 done with 299 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c04 done with 299 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g12_c01 done with 247 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c07 done with 133 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c05 done with 162 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c04 done with 283 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c05 done with 461 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g19_c01 done with 100 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g22_c01 done with 166 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c05 done with 224 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c07 done with 471 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c06 done with 163 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g08_c03 done with 228 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g06_c05 done with 125 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g19_c03 done with 118 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g02_c04 done with 136 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g20_c04 done with 283 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g21_c04 done with 84 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c04 done with 228 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g06_c01 done with 222 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g22_c02 done with 197 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g04_c02 done with 132 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c01 done with 482 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g19_c02 done with 116 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c03 done with 445 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g07_c04 done with 466 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g17_c06 done with 483 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g23_c05 done with 197 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g16_c05 done with 200 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c05 done with 236 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c02 done with 377 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g23_c02 done with 300 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g10_c04 done with 101 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g08_c01 done with 236 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g22_c03 done with 174 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g16_c02 done with 129 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g06_c03 done with 250 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c07 done with 381 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g09_c02 done with 416 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c01 done with 389 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g11_c04 done with 275 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g18_c01 done with 250 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g14_c02 done with 112 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g25_c04 done with 236 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g18_c03 done with 225 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g24_c04 done with 105 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g15_c06 done with 289 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g03_c02 done with 138 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g13_c05 done with 230 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g20_c03 done with 250 frames
# BoxingSpeedBag/v_BoxingSpeedBag_g20_c02 done with 249 frames

# %%
# !cd mmaction/data_tools/ucf101/  && bash generate_filelist.sh
# Out:
# parse frames under folder data/ucf101/rawframes/
# 0 videos parsed
# 200 videos parsed
# 400 videos parsed
# 600 videos parsed
# 800 videos parsed
# 1000 videos parsed
# 1200 videos parsed
# 1400 videos parsed
# 1600 videos parsed
# 1800 videos parsed
# 2000 videos parsed
# 2200 videos parsed
# 2400 videos parsed
# 2600 videos parsed
# 2800 videos parsed
# 3000 videos parsed
# 3200 videos parsed
# 3400 videos parsed
# 3600 videos parsed
# 3800 videos parsed
# 4000 videos parsed
# 4200 videos parsed
# 4400 videos parsed
# 4600 videos parsed
# 4800 videos parsed
# 5000 videos parsed
# 5200 videos parsed
# 5400 videos parsed
# 5600 videos parsed
# 5800 videos parsed
# 6000 videos parsed
# 6200 videos parsed
# 6400 videos parsed
# 6600 videos parsed
# 6800 videos parsed
# 7000 videos parsed
# 7200 videos parsed
# 7400 videos parsed
# 7600 videos parsed
# 7800 videos parsed
# 8000 videos parsed
# 8200 videos parsed
# 8400 videos parsed
# 8600 videos parsed
# 8800 videos parsed
# 9000 videos parsed
# 9200 videos parsed
# 9400 videos parsed
# 9600 videos parsed
# 9800 videos parsed
# 10000 videos parsed
# 10200 videos parsed
# 10400 videos parsed
# 10600 videos parsed
# 10800 videos parsed
# 11000 videos parsed
# 11200 videos parsed
# 11400 videos parsed
# 11600 videos parsed
# 11800 videos parsed
# 12000 videos parsed
# 12200 videos parsed
# 12400 videos parsed
# 12600 videos parsed
# 12800 videos parsed
# 13000 videos parsed
# 13200 videos parsed
# frame folder analysis done
# Filelist for rawframes generated.
# Filelist for videos generated.

# %% [markdown]
# # Test a reference model

# %%
# !cd mmaction/ &&  wget -c https://open-mmlab.s3.ap-northeast-2.amazonaws.com/mmaction/models/ucf101/tsn_2d_rgb_bninception_seg3_f1s1_b32_g8-98160339.pth -P ./modelzoo/
# Out:
# --2019-09-20 17:29:37--  https://open-mmlab.s3.ap-northeast-2.amazonaws.com/mmaction/models/ucf101/tsn_2d_rgb_bninception_seg3_f1s1_b32_g8-98160339.pth
# Resolving open-mmlab.s3.ap-northeast-2.amazonaws.com (open-mmlab.s3.ap-northeast-2.amazonaws.com)... 52.219.56.91
# Connecting to open-mmlab.s3.ap-northeast-2.amazonaws.com (open-mmlab.s3.ap-northeast-2.amazonaws.com)|52.219.56.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41660622 (40M) [application/x-www-form-urlencoded]
# Saving to: ‘./modelzoo/tsn_2d_rgb_bninception_seg3_f1s1_b32_g8-98160339.pth’
#
# tsn_2d_rgb_bnincept 100%[===================>]  39.73M  12.6MB/s    in 3.1s
#
# 2019-09-20 17:29:41 (12.6 MB/s) - ‘./modelzoo/tsn_2d_rgb_bninception_seg3_f1s1_b32_g8-98160339.pth’ saved [41660622/41660622]

# %%
# !cd mmaction/  &&  python tools/test_recognizer.py configs/ucf101/tsn_rgb_bninception.py modelzoo/tsn_2d_rgb_bninception_seg3_f1s1_b32_g8-98160339.pth --gpus 1
# Out:
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# terminal width is too small (0), please consider widen the terminal for better progressbar visualization
# [>>>>>>>>>>] 3783/3783, 1.1 task/s, elapsed: 3373s, ETA:     0sAveraging score over 1 clips without softmax (ie, raw)
# Mean Class Accuracy = 86.30
# Top-1 Accuracy = 86.41
# Top-5 Accuracy = 98.04
